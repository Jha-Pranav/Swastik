# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
df_summary_t2d = pd.read_excel('../data/Shanghai_DM/Shanghai_T2DM_Summary.xlsx')
df_summary_t1d = pd.read_excel('../data/Shanghai_DM/Shanghai_T1DM_Summary.xlsx')

# %%
corr = df_summary_t1d[['Fasting Plasma Glucose (mg/dl)',
       '2-hour Postprandial Plasma Glucose (mg/dl)',
       'Fasting C-peptide (nmol/L)', '2-hour Postprandial C-peptide (nmol/L)',
       'Fasting Insulin (pmol/L)', #'2-hour Postprandial insulin (pmol/L)',
       'HbA1c (mmol/mol)', 'Glycated Albumin (%)',
       'Total Cholesterol (mmol/L)', 'Triglyceride (mmol/L)',
       'High-Density Lipoprotein Cholesterol (mmol/L)',
       'Low-Density Lipoprotein Cholesterol (mmol/L)', 'Creatinine (umol/L)',
       'Estimated Glomerular Filtration Rate  (ml/min/1.73m2) ',
       'Uric Acid (mmol/L)', 'Blood Urea Nitrogen (mmol/L)']].applymap(lambda x: np.nan if x== "/" else x).dropna().corr()

# %%
corr[corr > 0.5]
# Out:
#                                                     Fasting Plasma Glucose (mg/dl)  \
# Fasting Plasma Glucose (mg/dl)                                                 1.0
# 2-hour Postprandial Plasma Glucose (mg/dl)                                     NaN
# Fasting C-peptide (nmol/L)                                                     NaN
# 2-hour Postprandial C-peptide (nmol/L)                                         NaN
# Fasting Insulin (pmol/L)                                                       NaN
# HbA1c (mmol/mol)                                                               NaN
# Glycated Albumin (%)                                                           NaN
# Total Cholesterol (mmol/L)                                                     NaN
# Triglyceride (mmol/L)                                                          NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                                  NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                                   NaN
# Creatinine (umol/L)                                                            NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                             NaN
# Uric Acid (mmol/L)                                                             NaN
# Blood Urea Nitrogen (mmol/L)                                                   NaN
#
#                                                     2-hour Postprandial Plasma Glucose (mg/dl)  \
# Fasting Plasma Glucose (mg/dl)                                                             NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                                                 1.0
# Fasting C-peptide (nmol/L)                                                                 NaN
# 2-hour Postprandial C-peptide (nmol/L)                                                     NaN
# Fasting Insulin (pmol/L)                                                                   NaN
# HbA1c (mmol/mol)                                                                           NaN
# Glycated Albumin (%)                                                                       NaN
# Total Cholesterol (mmol/L)                                                                 NaN
# Triglyceride (mmol/L)                                                                      NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                                              NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                                               NaN
# Creatinine (umol/L)                                                                        NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                                         NaN
# Uric Acid (mmol/L)                                                                         NaN
# Blood Urea Nitrogen (mmol/L)                                                               NaN
#
#                                                     Fasting C-peptide (nmol/L)  \
# Fasting Plasma Glucose (mg/dl)                                             NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                                 NaN
# Fasting C-peptide (nmol/L)                                            1.000000
# 2-hour Postprandial C-peptide (nmol/L)                                0.976589
# Fasting Insulin (pmol/L)                                                   NaN
# HbA1c (mmol/mol)                                                           NaN
# Glycated Albumin (%)                                                       NaN
# Total Cholesterol (mmol/L)                                            0.700495
# Triglyceride (mmol/L)                                                      NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                              NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                          0.506095
# Creatinine (umol/L)                                                        NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                         NaN
# Uric Acid (mmol/L)                                                         NaN
# Blood Urea Nitrogen (mmol/L)                                               NaN
#
#                                                     2-hour Postprandial C-peptide (nmol/L)  \
# Fasting Plasma Glucose (mg/dl)                                                         NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                                             NaN
# Fasting C-peptide (nmol/L)                                                        0.976589
# 2-hour Postprandial C-peptide (nmol/L)                                            1.000000
# Fasting Insulin (pmol/L)                                                               NaN
# HbA1c (mmol/mol)                                                                       NaN
# Glycated Albumin (%)                                                                   NaN
# Total Cholesterol (mmol/L)                                                        0.626523
# Triglyceride (mmol/L)                                                                  NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                                          NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                                           NaN
# Creatinine (umol/L)                                                                    NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                                     NaN
# Uric Acid (mmol/L)                                                                     NaN
# Blood Urea Nitrogen (mmol/L)                                                           NaN
#
#                                                     Fasting Insulin (pmol/L)  \
# Fasting Plasma Glucose (mg/dl)                                           NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                               NaN
# Fasting C-peptide (nmol/L)                                               NaN
# 2-hour Postprandial C-peptide (nmol/L)                                   NaN
# Fasting Insulin (pmol/L)                                            1.000000
# HbA1c (mmol/mol)                                                         NaN
# Glycated Albumin (%)                                                     NaN
# Total Cholesterol (mmol/L)                                               NaN
# Triglyceride (mmol/L)                                               0.886070
# High-Density Lipoprotein Cholesterol (mmol/L)                            NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                        0.537294
# Creatinine (umol/L)                                                      NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                       NaN
# Uric Acid (mmol/L)                                                  0.512542
# Blood Urea Nitrogen (mmol/L)                                             NaN
#
#                                                     HbA1c (mmol/mol)  \
# Fasting Plasma Glucose (mg/dl)                                   NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                       NaN
# Fasting C-peptide (nmol/L)                                       NaN
# 2-hour Postprandial C-peptide (nmol/L)                           NaN
# Fasting Insulin (pmol/L)                                         NaN
# HbA1c (mmol/mol)                                            1.000000
# Glycated Albumin (%)                                        0.962364
# Total Cholesterol (mmol/L)                                       NaN
# Triglyceride (mmol/L)                                            NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                    NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                     NaN
# Creatinine (umol/L)                                              NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...          0.709809
# Uric Acid (mmol/L)                                               NaN
# Blood Urea Nitrogen (mmol/L)                                     NaN
#
#                                                     Glycated Albumin (%)  \
# Fasting Plasma Glucose (mg/dl)                                       NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                           NaN
# Fasting C-peptide (nmol/L)                                           NaN
# 2-hour Postprandial C-peptide (nmol/L)                               NaN
# Fasting Insulin (pmol/L)                                             NaN
# HbA1c (mmol/mol)                                                0.962364
# Glycated Albumin (%)                                            1.000000
# Total Cholesterol (mmol/L)                                           NaN
# Triglyceride (mmol/L)                                                NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                        NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                         NaN
# Creatinine (umol/L)                                                  NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...              0.736294
# Uric Acid (mmol/L)                                                   NaN
# Blood Urea Nitrogen (mmol/L)                                         NaN
#
#                                                     Total Cholesterol (mmol/L)  \
# Fasting Plasma Glucose (mg/dl)                                             NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                                 NaN
# Fasting C-peptide (nmol/L)                                            0.700495
# 2-hour Postprandial C-peptide (nmol/L)                                0.626523
# Fasting Insulin (pmol/L)                                                   NaN
# HbA1c (mmol/mol)                                                           NaN
# Glycated Albumin (%)                                                       NaN
# Total Cholesterol (mmol/L)                                            1.000000
# Triglyceride (mmol/L)                                                      NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                              NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                          0.713897
# Creatinine (umol/L)                                                        NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                         NaN
# Uric Acid (mmol/L)                                                         NaN
# Blood Urea Nitrogen (mmol/L)                                               NaN
#
#                                                     Triglyceride (mmol/L)  \
# Fasting Plasma Glucose (mg/dl)                                        NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                            NaN
# Fasting C-peptide (nmol/L)                                            NaN
# 2-hour Postprandial C-peptide (nmol/L)                                NaN
# Fasting Insulin (pmol/L)                                         0.886070
# HbA1c (mmol/mol)                                                      NaN
# Glycated Albumin (%)                                                  NaN
# Total Cholesterol (mmol/L)                                            NaN
# Triglyceride (mmol/L)                                            1.000000
# High-Density Lipoprotein Cholesterol (mmol/L)                         NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                     0.729820
# Creatinine (umol/L)                                                   NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                    NaN
# Uric Acid (mmol/L)                                               0.602121
# Blood Urea Nitrogen (mmol/L)                                          NaN
#
#                                                     High-Density Lipoprotein Cholesterol (mmol/L)  \
# Fasting Plasma Glucose (mg/dl)                                                                NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                                                    NaN
# Fasting C-peptide (nmol/L)                                                                    NaN
# 2-hour Postprandial C-peptide (nmol/L)                                                        NaN
# Fasting Insulin (pmol/L)                                                                      NaN
# HbA1c (mmol/mol)                                                                              NaN
# Glycated Albumin (%)                                                                          NaN
# Total Cholesterol (mmol/L)                                                                    NaN
# Triglyceride (mmol/L)                                                                         NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                                                 1.0
# Low-Density Lipoprotein Cholesterol (mmol/L)                                                  NaN
# Creatinine (umol/L)                                                                           NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                                            NaN
# Uric Acid (mmol/L)                                                                            NaN
# Blood Urea Nitrogen (mmol/L)                                                                  NaN
#
#                                                     Low-Density Lipoprotein Cholesterol (mmol/L)  \
# Fasting Plasma Glucose (mg/dl)                                                               NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                                                   NaN
# Fasting C-peptide (nmol/L)                                                              0.506095
# 2-hour Postprandial C-peptide (nmol/L)                                                       NaN
# Fasting Insulin (pmol/L)                                                                0.537294
# HbA1c (mmol/mol)                                                                             NaN
# Glycated Albumin (%)                                                                         NaN
# Total Cholesterol (mmol/L)                                                              0.713897
# Triglyceride (mmol/L)                                                                   0.729820
# High-Density Lipoprotein Cholesterol (mmol/L)                                                NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                                            1.000000
# Creatinine (umol/L)                                                                          NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                                           NaN
# Uric Acid (mmol/L)                                                                      0.636482
# Blood Urea Nitrogen (mmol/L)                                                                 NaN
#
#                                                     Creatinine (umol/L)  \
# Fasting Plasma Glucose (mg/dl)                                      NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                          NaN
# Fasting C-peptide (nmol/L)                                          NaN
# 2-hour Postprandial C-peptide (nmol/L)                              NaN
# Fasting Insulin (pmol/L)                                            NaN
# HbA1c (mmol/mol)                                                    NaN
# Glycated Albumin (%)                                                NaN
# Total Cholesterol (mmol/L)                                          NaN
# Triglyceride (mmol/L)                                               NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                       NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                        NaN
# Creatinine (umol/L)                                                 1.0
# Estimated Glomerular Filtration Rate  (ml/min/1...                  NaN
# Uric Acid (mmol/L)                                                  NaN
# Blood Urea Nitrogen (mmol/L)                                        NaN
#
#                                                     Estimated Glomerular Filtration Rate  (ml/min/1.73m2)   \
# Fasting Plasma Glucose (mg/dl)                                                                    NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                                                        NaN
# Fasting C-peptide (nmol/L)                                                                        NaN
# 2-hour Postprandial C-peptide (nmol/L)                                                            NaN
# Fasting Insulin (pmol/L)                                                                          NaN
# HbA1c (mmol/mol)                                                                             0.709809
# Glycated Albumin (%)                                                                         0.736294
# Total Cholesterol (mmol/L)                                                                        NaN
# Triglyceride (mmol/L)                                                                             NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                                                     NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                                                      NaN
# Creatinine (umol/L)                                                                               NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                                           1.000000
# Uric Acid (mmol/L)                                                                                NaN
# Blood Urea Nitrogen (mmol/L)                                                                      NaN
#
#                                                     Uric Acid (mmol/L)  \
# Fasting Plasma Glucose (mg/dl)                                     NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                         NaN
# Fasting C-peptide (nmol/L)                                         NaN
# 2-hour Postprandial C-peptide (nmol/L)                             NaN
# Fasting Insulin (pmol/L)                                      0.512542
# HbA1c (mmol/mol)                                                   NaN
# Glycated Albumin (%)                                               NaN
# Total Cholesterol (mmol/L)                                         NaN
# Triglyceride (mmol/L)                                         0.602121
# High-Density Lipoprotein Cholesterol (mmol/L)                      NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                  0.636482
# Creatinine (umol/L)                                                NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                 NaN
# Uric Acid (mmol/L)                                            1.000000
# Blood Urea Nitrogen (mmol/L)                                       NaN
#
#                                                     Blood Urea Nitrogen (mmol/L)
# Fasting Plasma Glucose (mg/dl)                                               NaN
# 2-hour Postprandial Plasma Glucose (mg/dl)                                   NaN
# Fasting C-peptide (nmol/L)                                                   NaN
# 2-hour Postprandial C-peptide (nmol/L)                                       NaN
# Fasting Insulin (pmol/L)                                                     NaN
# HbA1c (mmol/mol)                                                             NaN
# Glycated Albumin (%)                                                         NaN
# Total Cholesterol (mmol/L)                                                   NaN
# Triglyceride (mmol/L)                                                        NaN
# High-Density Lipoprotein Cholesterol (mmol/L)                                NaN
# Low-Density Lipoprotein Cholesterol (mmol/L)                                 NaN
# Creatinine (umol/L)                                                          NaN
# Estimated Glomerular Filtration Rate  (ml/min/1...                           NaN
# Uric Acid (mmol/L)                                                           NaN
# Blood Urea Nitrogen (mmol/L)                                                 1.0
